# %%
import pandas as pd
data = pd.read_csv('globalterrorismdb_shorter.csv')
data.head(5)
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate    ...    nkill  nkillter  \
# 0       2  Central America & Caribbean       NaN    ...      1.0       NaN
# 1       1                North America       NaN    ...      0.0       NaN
# 2       5               Southeast Asia    Tarlac    ...      1.0       NaN
# 3       8               Western Europe    Attica    ...      NaN       NaN
# 4       4                    East Asia       NaN    ...      NaN       NaN
#
#    nwound  nwoundte  property propextent propextent_txt  ishostkid  nhostkid  \
# 0     0.0       NaN         0        NaN            NaN        0.0       NaN
# 1     0.0       NaN         0        NaN            NaN        1.0       1.0
# 2     0.0       NaN         0        NaN            NaN        0.0       NaN
# 3     NaN       NaN         1        NaN            NaN        0.0       NaN
# 4     NaN       NaN         1        NaN            NaN        0.0       NaN
#
#    dbsource
# 0      PGIS
# 1      PGIS
# 2      PGIS
# 3      PGIS
# 4      PGIS
#
# [5 rows x 58 columns]

# %%
subdata = data[["iyear", "country_txt", "location", "attacktype1_txt", "weaptype1_txt", "gname"]]
subdata.head(10)
# Out:
#    iyear         country_txt         location                 attacktype1_txt  \
# 0   1970  Dominican Republic              NaN                   Assassination
# 1   1970              Mexico              NaN     Hostage Taking (Kidnapping)
# 2   1970         Philippines              NaN                   Assassination
# 3   1970              Greece              NaN               Bombing/Explosion
# 4   1970               Japan              NaN  Facility/Infrastructure Attack
# 5   1970       United States              NaN                   Armed Assault
# 6   1970             Uruguay              NaN                   Assassination
# 7   1970       United States  Edes Substation               Bombing/Explosion
# 8   1970       United States              NaN  Facility/Infrastructure Attack
# 9   1970       United States              NaN  Facility/Infrastructure Attack
#
#                weaptype1_txt                               gname
# 0                    Unknown                              MANO-D
# 1                    Unknown  23rd of September Communist League
# 2                    Unknown                             Unknown
# 3  Explosives/Bombs/Dynamite                             Unknown
# 4                 Incendiary                             Unknown
# 5                   Firearms                  Black Nationalists
# 6                   Firearms                 Tupamaros (Uruguay)
# 7  Explosives/Bombs/Dynamite                             Unknown
# 8                 Incendiary                     New Year's Gang
# 9                 Incendiary                     New Year's Gang

# %%
subdata = subdata.dropna(axis=0, how='any')
subdata.head(10)
# Out:
#     iyear    country_txt                     location  \
# 7    1970  United States              Edes Substation
# 14   1970  United States      Caparra Shopping Center
# 17   1970  United States                     Brooklyn
# 20   1970  United States  Champaign Police Department
# 22   1970  United States           Seattle University
# 24   1970  United States            Front of building
# 30   1970  United States                    Manhattan
# 32   1970  United States                       Queens
# 35   1970  United States            Front of building
# 36   1970  United States              210 East 10 St.
#
#                    attacktype1_txt              weaptype1_txt  \
# 7                Bombing/Explosion  Explosives/Bombs/Dynamite
# 14  Facility/Infrastructure Attack                 Incendiary
# 17               Bombing/Explosion  Explosives/Bombs/Dynamite
# 20  Facility/Infrastructure Attack                 Incendiary
# 22               Bombing/Explosion  Explosives/Bombs/Dynamite
# 24  Facility/Infrastructure Attack                 Incendiary
# 30                   Armed Assault                   Firearms
# 32                   Armed Assault                   Firearms
# 35               Bombing/Explosion  Explosives/Bombs/Dynamite
# 36               Bombing/Explosion  Explosives/Bombs/Dynamite
#
#                             gname
# 7                         Unknown
# 14  Armed Commandos of Liberation
# 17             Black Nationalists
# 20             Black Nationalists
# 22             Black Nationalists
# 24               White extremists
# 30             Black Nationalists
# 32             Black Nationalists
# 35               White extremists
# 36                       Strikers

# %%
cleaned_data = subdata[(subdata["country_txt"]=="United Kingdom") & (subdata["attacktype1_txt"]!="Unknown") 
                       & (subdata["weaptype1_txt"]!="Unknown") & (subdata["gname"]!="Unknown") 
                       & ((subdata["iyear"]>=1995) & (subdata["iyear"]<=2016))]

cleaned_data.head(15)
# Out:
#        iyear     country_txt  \
# 62579   1996  United Kingdom
# 67438   1998  United Kingdom
# 67451   1998  United Kingdom
# 67460   1998  United Kingdom
# 67478   1998  United Kingdom
# 67486   1998  United Kingdom
# 67487   1998  United Kingdom
# 67504   1998  United Kingdom
# 67538   1998  United Kingdom
# 67539   1998  United Kingdom
# 67576   1998  United Kingdom
# 67591   1998  United Kingdom
# 67594   1998  United Kingdom
# 67611   1998  United Kingdom
# 67613   1998  United Kingdom
#
#                                                 location    attacktype1_txt  \
# 62579  Corporation Street outside the Arndale shoppin...  Bombing/Explosion
# 67438                             Belfast (Capital City)      Armed Assault
# 67451                                        County Down  Bombing/Explosion
# 67460                             Belfast (Capital City)      Armed Assault
# 67478                               Londonderry (County)      Armed Assault
# 67486                             Belfast (Capital City)      Armed Assault
# 67487                             Belfast (Capital City)      Armed Assault
# 67504                                 Fermanagh (County)  Bombing/Explosion
# 67538                             Belfast (Capital City)      Armed Assault
# 67539                             Belfast (Capital City)      Armed Assault
# 67576                                      Down (County)  Bombing/Explosion
# 67591                                    Armagh (County)  Bombing/Explosion
# 67594                             Belfast (Capital City)  Bombing/Explosion
# 67611                             Belfast (Capital City)  Bombing/Explosion
# 67613                                  Ulster (Province)      Armed Assault
#
#                    weaptype1_txt                                    gname
# 62579  Explosives/Bombs/Dynamite              Irish Republican Army (IRA)
# 67438                   Firearms          Loyalist Volunteer Forces (LVF)
# 67451  Explosives/Bombs/Dynamite  Continuity Irish Republican Army (CIRA)
# 67460                   Firearms          Loyalist Volunteer Forces (LVF)
# 67478                   Firearms          Loyalist Volunteer Forces (LVF)
# 67486                   Firearms    Irish National Liberation Army (INLA)
# 67487                   Firearms    Irish National Liberation Army (INLA)
# 67504  Explosives/Bombs/Dynamite  Continuity Irish Republican Army (CIRA)
# 67538                   Firearms              Irish Republican Army (IRA)
# 67539                   Firearms              Irish Republican Army (IRA)
# 67576  Explosives/Bombs/Dynamite              Irish Republican Army (IRA)
# 67591  Explosives/Bombs/Dynamite              Irish Republican Army (IRA)
# 67594  Explosives/Bombs/Dynamite              Irish Republican Army (IRA)
# 67611  Explosives/Bombs/Dynamite    Irish National Liberation Army (INLA)
# 67613                   Firearms  Continuity Irish Republican Army (CIRA)

# %%
listOfGroups = cleaned_data["gname"].value_counts()
listOfGroups[:20]
# Out:
# Dissident Republicans                                    54
# Real Irish Republican Army (RIRA)                        36
# Irish Republican Army (IRA)                              33
# Oglaigh na hEireann                                      28
# Red Hand Defenders (RHD)                                 23
# Loyalists                                                21
# Continuity Irish Republican Army (CIRA)                  21
# Irish Republican Extremists                              17
# Loyalist Volunteer Forces (LVF)                          15
# The New Irish Republican Army                            15
# Protestant extremists                                    14
# Ulster Volunteer Force (UVF)                             14
# Ulster Freedom Fighters (UFF)                            14
# Animal Rights extremists                                 11
# Orange Volunteers (OV)                                   11
# Irish National Liberation Army (INLA)                     8
# Secret Organization of al-Qaida in Europe                 4
# Real Ulster Freedom Fighters (UFF) - Northern Ireland     4
# Animal Liberation Front (ALF)                             4
# Muslim extremists                                         2
# Name: gname, dtype: int64

# %%
listOfAttacks = cleaned_data["attacktype1_txt"].value_counts()
listOfAttacks
# Out:
# Bombing/Explosion                 231
# Armed Assault                      83
# Facility/Infrastructure Attack     41
# Assassination                       9
# Hijacking                           8
# Unarmed Assault                     7
# Hostage Taking (Kidnapping)         4
# Name: attacktype1_txt, dtype: int64

# %%
##after = cleaned_data.groupby('gname').count()

import matplotlib.pyplot as plt

listOfGroups = listOfGroups[:10]
#listOfGroups

plt.figure(figsize=(24,12))

plt.rcParams.update({'font.size': 16})

listOfGroups.plot.pie(x="y".index,
               shadow=False,   # exploding 'Friday'
               startangle=90,
               autopct='%1.1f%%')

plt.axis('equal')
plt.tight_layout()

plt.title("Top 10 Organisations & Frequency of Attacks")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import matplotlib.pyplot as plt

listOfAttacks.plot.bar()
plt.ylabel("Frequency")
plt.xlabel("Type of Attack")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
listOfYears = cleaned_data["iyear"].value_counts()
listOfYears = listOfYears.sort_index()
listOfYears
# Out:
# 1996     1
# 1998    42
# 1999    39
# 2000    39
# 2001    56
# 2002    10
# 2003    14
# 2004     3
# 2005    11
# 2006     3
# 2007     7
# 2008     5
# 2009    10
# 2010    17
# 2011     5
# 2012    13
# 2013    32
# 2014    13
# 2015    34
# 2016    29
# Name: iyear, dtype: int64

# %%
listOfYears.plot()
plt.ylabel("No. of Terrorist Attacks in the UK")
plt.xlabel("Year")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
listOfLocations = cleaned_data["location"].value_counts()
listOfLocations.plot

# %%
from mpl_toolkits.basemap import Basemap

# %%
#m = Basemap(projection='mill', lat_0=55.3781,lon_0=3.4360)

m = Basemap(projection='lcc', lat_0 = 55, lon_0 = -4,
    resolution = 'l', area_thresh = 0.05,
    llcrnrlon=-9, llcrnrlat=49,
    urcrnrlon=2, urcrnrlat=61)



plt.figure(figsize=(24,12))

m.drawcoastlines()
m.drawcountries()

UKlat, UKlon = 54.611018,-5.934137
xpt, ypt = m(UKlon, UKlat)
m.plot(xpt, ypt, "co")

plt.title('UK')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
