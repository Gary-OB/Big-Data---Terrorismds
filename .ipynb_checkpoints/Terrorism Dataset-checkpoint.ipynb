# %%
import pandas as pd
data = pd.read_csv('globalterrorismdb_shorter.csv')
data.head(5)
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate    ...    nkill  nkillter  \
# 0       2  Central America & Caribbean       NaN    ...      1.0       NaN
# 1       1                North America       NaN    ...      0.0       NaN
# 2       5               Southeast Asia    Tarlac    ...      1.0       NaN
# 3       8               Western Europe    Attica    ...      NaN       NaN
# 4       4                    East Asia       NaN    ...      NaN       NaN
#
#    nwound  nwoundte  property propextent propextent_txt  ishostkid  nhostkid  \
# 0     0.0       NaN         0        NaN            NaN        0.0       NaN
# 1     0.0       NaN         0        NaN            NaN        1.0       1.0
# 2     0.0       NaN         0        NaN            NaN        0.0       NaN
# 3     NaN       NaN         1        NaN            NaN        0.0       NaN
# 4     NaN       NaN         1        NaN            NaN        0.0       NaN
#
#    dbsource
# 0      PGIS
# 1      PGIS
# 2      PGIS
# 3      PGIS
# 4      PGIS
#
# [5 rows x 58 columns]

# %%
subdata = data[["iyear", "country_txt", "attacktype1_txt", "gname", "weaptype1_txt"]]
subdata.head(10)
# Out:
#    iyear         country_txt                 attacktype1_txt  \
# 0   1970  Dominican Republic                   Assassination
# 1   1970              Mexico     Hostage Taking (Kidnapping)
# 2   1970         Philippines                   Assassination
# 3   1970              Greece               Bombing/Explosion
# 4   1970               Japan  Facility/Infrastructure Attack
# 5   1970       United States                   Armed Assault
# 6   1970             Uruguay                   Assassination
# 7   1970       United States               Bombing/Explosion
# 8   1970       United States  Facility/Infrastructure Attack
# 9   1970       United States  Facility/Infrastructure Attack
#
#                                 gname              weaptype1_txt
# 0                              MANO-D                    Unknown
# 1  23rd of September Communist League                    Unknown
# 2                             Unknown                    Unknown
# 3                             Unknown  Explosives/Bombs/Dynamite
# 4                             Unknown                 Incendiary
# 5                  Black Nationalists                   Firearms
# 6                 Tupamaros (Uruguay)                   Firearms
# 7                             Unknown  Explosives/Bombs/Dynamite
# 8                     New Year's Gang                 Incendiary
# 9                     New Year's Gang                 Incendiary

# %%
subdata = subdata.dropna(axis=0, how='any')
subdata.head(10)
# Out:
#    iyear         country_txt                 attacktype1_txt  \
# 0   1970  Dominican Republic                   Assassination
# 1   1970              Mexico     Hostage Taking (Kidnapping)
# 2   1970         Philippines                   Assassination
# 3   1970              Greece               Bombing/Explosion
# 4   1970               Japan  Facility/Infrastructure Attack
# 5   1970       United States                   Armed Assault
# 6   1970             Uruguay                   Assassination
# 7   1970       United States               Bombing/Explosion
# 8   1970       United States  Facility/Infrastructure Attack
# 9   1970       United States  Facility/Infrastructure Attack
#
#                                 gname              weaptype1_txt
# 0                              MANO-D                    Unknown
# 1  23rd of September Communist League                    Unknown
# 2                             Unknown                    Unknown
# 3                             Unknown  Explosives/Bombs/Dynamite
# 4                             Unknown                 Incendiary
# 5                  Black Nationalists                   Firearms
# 6                 Tupamaros (Uruguay)                   Firearms
# 7                             Unknown  Explosives/Bombs/Dynamite
# 8                     New Year's Gang                 Incendiary
# 9                     New Year's Gang                 Incendiary

# %%
cleaned_data = subdata[(subdata["country_txt"]=="United Kingdom") & (subdata["attacktype1_txt"]!="Unknown") 
        & (subdata["gname"]!="Unknown") 
        & (subdata["weaptype1_txt"]!="Unknown") & ((subdata["iyear"]>=1990) & (subdata["iyear"]<=2016))]

cleaned_data.head(15)
# Out:
#        iyear     country_txt    attacktype1_txt                        gname  \
# 41009   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41019   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41044   1990  United Kingdom      Assassination        Protestant extremists
# 41077   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41094   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41095   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41099   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41134   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41135   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41147   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41148   1990  United Kingdom      Assassination  Irish Republican Army (IRA)
# 41157   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41181   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41189   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
# 41195   1990  United Kingdom  Bombing/Explosion  Irish Republican Army (IRA)
#
#                    weaptype1_txt
# 41009  Explosives/Bombs/Dynamite
# 41019  Explosives/Bombs/Dynamite
# 41044                   Firearms
# 41077                   Firearms
# 41094  Explosives/Bombs/Dynamite
# 41095  Explosives/Bombs/Dynamite
# 41099  Explosives/Bombs/Dynamite
# 41134  Explosives/Bombs/Dynamite
# 41135  Explosives/Bombs/Dynamite
# 41147  Explosives/Bombs/Dynamite
# 41148  Explosives/Bombs/Dynamite
# 41157  Explosives/Bombs/Dynamite
# 41181  Explosives/Bombs/Dynamite
# 41189  Explosives/Bombs/Dynamite
# 41195  Explosives/Bombs/Dynamite

# %%
listOfGroups = cleaned_data["gname"].value_counts()
listOfGroups[:20]
# Out:
# Irish Republican Army (IRA)                      683
# Dissident Republicans                             84
# Protestant extremists                             79
# Ulster Freedom Fighters (UFF)                     77
# Ulster Volunteer Force (UVF)                      56
# Oglaigh na hEireann                               39
# Real Irish Republican Army (RIRA)                 37
# Irish National Liberation Army (INLA)             34
# Continuity Irish Republican Army (CIRA)           30
# The New Irish Republican Army                     30
# Loyalists                                         27
# Red Hand Defenders (RHD)                          23
# Irish Republican Extremists                       21
# Loyalist Volunteer Forces (LVF)                   20
# Animal Rights extremists                          13
# Orange Volunteers (OV)                            11
# Irish People's Liberation Organization (IPLO)     10
# Animal Liberation Front (ALF)                      9
# Informal Anarchist Federation                      9
# Anarchists                                         7
# Name: gname, dtype: int64

# %%
listOfAttacks = cleaned_data["attacktype1_txt"].value_counts()
listOfAttacks
# Out:
# Bombing/Explosion                      607
# Assassination                          297
# Facility/Infrastructure Attack         247
# Armed Assault                          197
# Unarmed Assault                         12
# Hostage Taking (Kidnapping)              9
# Hijacking                                9
# Hostage Taking (Barricade Incident)      3
# Name: attacktype1_txt, dtype: int64

# %%
##after = cleaned_data.groupby('gname').count()



listOfGroups = listOfGroups[:5]
#listOfGroups

listOfGroups.plot.pie(x="y".index,
               shadow=False,   # exploding 'Friday'
               startangle=90,
               autopct='%1.1f%%')

plt.axis('equal')
plt.tight_layout()
plt.title("Top 10 Organisations & Frequency of Attacks")
plt.show()

# %%
import matplotlib.pyplot as plt

listOfAttacks.plot.bar()
plt.ylabel("Frequency")
plt.xlabel("Type of Attack")
plt.show()

# %%
listOfYears = cleaned_data["iyear"].value_counts()
listOfYears = listOfYears.sort_index()
listOfYears
# Out:
# 1990    134
# 1991    239
# 1992    243
# 1994    213
# 1995      9
# 1996     23
# 1997     38
# 1998     42
# 1999     39
# 2000     39
# 2001     57
# 2002     10
# 2003     14
# 2004      3
# 2005     13
# 2006      3
# 2007      9
# 2008      5
# 2009     10
# 2010     19
# 2011      6
# 2012     25
# 2013     57
# 2014     43
# 2015     52
# 2016     36
# Name: iyear, dtype: int64

# %%
listOfYears.plot()
plt.ylabel("No. of Terrorist Attacks in the UK")
plt.xlabel("Year")
plt.show()
